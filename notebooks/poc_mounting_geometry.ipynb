# %% [markdown]
# # PoC: Mounting + Geometry Batch Extraction
#
# This notebook wraps `scripts/poc_mounting_geometry.py` and keeps all core logic in the script.

# %% [markdown]
# ## Expected input CSV
# Required columns: `site_id, latitude, longitude` (optional `polygon_wkt`).

# %%
# !python scripts/poc_mounting_geometry.py --help

# %%
# Example run using pre-existing images in outputs/
# !python scripts/poc_mounting_geometry.py \
    --input-csv data/poc_sites_template.csv \
    --output-csv outputs/poc_results.csv \
    --outputs-dir outputs \
    --existing-image-dir outputs

# %%
import pandas as pd
pd.read_csv('outputs/poc_results.csv').head()
